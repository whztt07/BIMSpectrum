# %%
import ifcopenshell as ifc
import json
path = "/home/ubuntu/workspace/tempfiles/test.ifc"
file = ifc.open(path)
num=file.wrapped_data.entity_names()
file_id = "5654bfa9d737bd7e94b37e6c"
data=list()

for i in num:
    entity = file.wrapped_data.by_id(i)
    entity_data = {"line_id":entity.id(),"type": entity.is_a(),"content": entity.__str__(),"file_id":file_id, "project_id":file_id}
    for j in xrange(entity.__len__()):
        try:
            entity_data[entity.get_argument_name(j)]=entity.get_argument(j).id()
        except:
            import types
            if isinstance(entity.get_argument(j), list):
                entity_data[entity.get_argument_name(j)]=list()
                for v in entity.get_argument(j):
                    try:
                        entity_data[entity.get_argument_name(j)].append(v.id())
                    except:
                        entity_data[entity.get_argument_name(j)].append(v)
            else:
                entity_data[entity.get_argument_name(j)]=entity.get_argument(j)
    data.append(entity_data)
print json.dumps(data)
# Out:
# [{"GivenName": null, "Addresses": null, "Roles": null, "FamilyName": "Undefined", "content": "#1=IfcPerson('DESKTOP-KSS1N7O\\malin','Undefined',$,$,$,$,$,$)", "line_id": 1, "file_id": "5654bfa9d737bd7e94b37e6c", "SuffixTitles": null, "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcPerson", "Id": "DESKTOP-KSS1N7O\\malin", "MiddleNames": null, "PrefixTitles": null}, {"Name": "Tekla Corporation", "Roles": null, "content": "#2=IfcOrganization($,'Tekla Corporation',$,$,$)", "line_id": 2, "Addresses": null, "file_id": "5654bfa9d737bd7e94b37e6c", "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcOrganization", "Id": null, "Description": null}, {"TheOrganization": 2, "Roles": null, "ThePerson": 1, "content": "#3=IfcPersonAndOrganization(#1,#2,$)", "line_id": 3, "file_id": "5654bfa9d737bd7e94b37e6c", "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcPersonAndOrganization"}, {"ApplicationIdentifier": "Multi material modeling", "content": "#4=IfcApplication(#2,'21.0 Service Release 1','Tekla Structures Educational','Multi material modeling')", "line_id": 4, "Version": "21.0 Service Release 1", "ApplicationDeveloper": 2, "file_id": "5654bfa9d737bd7e94b37e6c", "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcApplication", "ApplicationFullName": "Tekla Structures Educational"}, {"OwningUser": 3, "LastModifyingUser": null, "LastModifiedDate": null, "ChangeAction": "NOCHANGE", "content": "#5=IfcOwnerHistory(#3,#4,$,.NOCHANGE.,$,$,$,1438737194)", "line_id": 5, "State": null, "OwningApplication": 4, "file_id": "5654bfa9d737bd7e94b37e6c", "LastModifyingApplication": null, "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcOwnerHistory", "CreationDate": 1438737194}, {"Coordinates": [0.0, 0.0, 0.0], "content": "#6=IfcCartesianPoint((0.,0.,0.))", "line_id": 6, "file_id": "5654bfa9d737bd7e94b37e6c", "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcCartesianPoint"}, {"content": "#7=IfcDirection((1.,0.,0.))", "line_id": 7, "DirectionRatios": [1.0, 0.0, 0.0], "file_id": "5654bfa9d737bd7e94b37e6c", "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcDirection"}, {"content": "#8=IfcDirection((0.,1.,0.))", "line_id": 8, "DirectionRatios": [0.0, 1.0, 0.0], "file_id": "5654bfa9d737bd7e94b37e6c", "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcDirection"}, {"content": "#9=IfcDirection((0.,0.,1.))", "line_id": 9, "DirectionRatios": [0.0, 0.0, 1.0], "file_id": "5654bfa9d737bd7e94b37e6c", "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcDirection"}, {"Axis": 9, "content": "#10=IfcAxis2Placement3D(#6,#9,#7)", "line_id": 10, "file_id": "5654bfa9d737bd7e94b37e6c", "RefDirection": 7, "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcAxis2Placement3D", "Location": 6}, {"TrueNorth": null, "WorldCoordinateSystem": 10, "ContextIdentifier": null, "CoordinateSpaceDimension": 3, "Precision": 1e-05, "content": "#11=IfcGeometricRepresentationContext($,'Model',3,1.E-005,#10,$)", "line_id": 11, "ContextType": "Model", "file_id": "5654bfa9d737bd7e94b37e6c", "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcGeometricRepresentationContext"}, {"TrueNorth": null, "WorldCoordinateSystem": null, "UserDefinedTargetView": null, "ContextIdentifier": "Body", "CoordinateSpaceDimension": null, "Precision": null, "content": "#12=IfcGeometricRepresentationSubContext('Body','Model',*,*,*,*,#11,$,.MODEL_VIEW.,$)", "line_id": 12, "ContextType": "Model", "TargetScale": null, "file_id": "5654bfa9d737bd7e94b37e6c", "TargetView": "MODEL_VIEW", "ParentContext": 11, "project_id": "5654bfa9d737bd7e94b37e6c", "type": "IfcGeometricRepresentationSubContext"}, {"TrueNorth": null, "WorldCoordinateSystem": null, "UserDefinedTargetView": null, "ContextIdentifier": "Axis", "CoordinateSpaceDimension": null, "Precision": null, "content": "#13=IfcGeometricRepresentationSubContext('Axis','Model',*,*,*,*,#11,$,.GRAPH_VIEW.,$)", "line_id": 13, "ContextType": "Model", "TargetScale": null, "file_id": "5654bfa9d737bd7e94b37e6c", "TargetView": "GRAPH_VIEW", "ParentContex ...

# %%
entity = file.wrapped_data.by_id(24)
print entity
print entity.__len__()
entity_data = dict()
for j in xrange(entity.__len__()):
    try:
        entity_data[entity.get_argument_name(j)]=entity.get_argument(j).id()
    except:
        import types
        if isinstance(entity.get_argument(j), list):
            entity_data[entity.get_argument_name(j)]=list()
            for v in entity.get_argument(j):
                try:
                    entity_data[entity.get_argument_name(j)].append(v.id())
                except:
                    entity_data[entity.get_argument_name(j)].append(v)
        else:
            entity_data[entity.get_argument_name(j)].append(entity.get_argument(j))
print entity_data
# Out:
# #24=IfcUnitAssignment((#15,#16,#17,#18,#19,#20,#21,#22,#23))
# 1
# {'Units': [15, 16, 17, 18, 19, 20, 21, 22, 23]}

# %%
dd=entity.get_argument(0)
import types
isinstance(dd[0], list)
# Out:
# False

# %%
# data=list()
# for i in num:
#     entity = file.wrapped_data.by_id(i)
#     entity_data = {"line_id":entity.id(),"type": entity.is_a(),"content": entity.__str__(),"file_id":file_id}
#     for j in xrange(entity.__len__()):
#         try:
#             entity_data[entity.get_argument_name(j)]=entity.get_argument(j).id()
#         except:
#             entity_data[entity.get_argument_name(j)]=entity.get_argument(j)
#         data.append(entity_data)
print data

# %%
data=list()
for x in xrange(size):
    entity = file.wrapped_data.by_id(num[x])
    for i in xrange(entity.__len__()):
        keys[entity.id()][entity.get_argument_name(i)]=entity.get_argument(i)
    
    entity_data = {"line_id":entity.id(),"type": entity.is_a(),"content": entity.__str__(),"file_id":file_id}
    data.append(entity_data)
inx = 0
for item in data:
    item['_id']=objid[inx]['_id']
    inx+=1
keys = build_dict(data, key="line_id")
for x in xrange(2):
    entity = file.wrapped_data.by_id(num[x])
    for i in xrange(entity.__len__()):
        keys[entity.id()][entity.get_argument_name(i)]=entity.get_argument(i)
print keys

# %%
entity = file.wrapped_data.by_id(1325)
t=dict()
print entity
for i in xrange(entity.__len__()):
    try:
        t[entity.get_argument_name(i)]=entity.get_argument(i).id()
    except:
        t[entity.get_argument_name(i)]=entity.get_argument(i)
t
# Out:
# #1325=IfcFaceOuterBound(#1324,.T.)
# {'Bound': 1324, 'Orientation': True}

# %%
dir(entity.get_argument(0)).index('id')
# Out:
# 33

# %%
size=2
objid=[{'_id':"565616aed737bd1502599c2e"},{'_id':"565616aed737bd1502599c2f"}]

# %%
keys
# Out:
# {1: {'Addresses': None,
#   'FamilyName': 'Undefined',
#   'GivenName': None,
#   'Id': 'DESKTOP-KSS1N7O\\malin',
#   'MiddleNames': None,
#   'PrefixTitles': None,
#   'Roles': None,
#   'SuffixTitles': None,
#   '_id': '565616aed737bd1502599c2e',
#   'content': "#1=IfcPerson('DESKTOP-KSS1N7O\\malin','Undefined',$,$,$,$,$,$)",
#   'file_id': '5654bfa9d737bd7e94b37e6c',
#   'index': 0,
#   'line_id': 1,
#   'type': 'IfcPerson'},
#  2: {'Addresses': None,
#   'Description': None,
#   'Id': None,
#   'Name': 'Tekla Corporation',
#   'Roles': None,
#   '_id': '565616aed737bd1502599c2f',
#   'content': "#2=IfcOrganization($,'Tekla Corporation',$,$,$)",
#   'file_id': '5654bfa9d737bd7e94b37e6c',
#   'index': 1,
#   'line_id': 2,
#   'type': 'IfcOrganization'}}

# %%
enriched_data = list()
for key in keys:
    enriched_data.append(keys[key])
print enriched_data
# Out:
# [{'Roles': None, 'line_id': 1, 'file_id': '5654bfa9d737bd7e94b37e6c', 'GivenName': None, 'index': 0, 'Addresses': None, 'FamilyName': 'Undefined', 'content': "#1=IfcPerson('DESKTOP-KSS1N7O\\malin','Undefined',$,$,$,$,$,$)", 'PrefixTitles': None, 'SuffixTitles': None, '_id': '565616aed737bd1502599c2e', 'type': 'IfcPerson', 'Id': 'DESKTOP-KSS1N7O\\malin', 'MiddleNames': None}, {'Name': 'Tekla Corporation', 'Roles': None, 'line_id': 2, 'file_id': '5654bfa9d737bd7e94b37e6c', 'Description': None, 'index': 1, 'Addresses': None, 'content': "#2=IfcOrganization($,'Tekla Corporation',$,$,$)", '_id': '565616aed737bd1502599c2f', 'type': 'IfcOrganization', 'Id': None}]
